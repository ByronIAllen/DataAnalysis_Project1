# %%
# Dependencies
import pandas as pd
import matplotlib as plt
import numpy as np

# %%
econ_df = pd.read_csv(r"Resources/income_data.csv")
econ_df.head()
# Out:
#         id  State_Code State_Name State_ab          County            City  \
# 0  1011000           1    Alabama       AL   Mobile County       Chickasaw
# 1  1011010           1    Alabama       AL  Barbour County      Louisville
# 2  1011020           1    Alabama       AL   Shelby County      Columbiana
# 3  1011030           1    Alabama       AL   Mobile County         Satsuma
# 4  1011040           1    Alabama       AL   Mobile County  Dauphin Island
#
#              Place  Type Primary  Zip_Code Area_Code     ALand     AWater  \
# 0   Chickasaw city  City   place     36611       251  10894952     909156
# 1        Clio city  City   place     36048       334  26070325      23254
# 2  Columbiana city  City   place     35051       205  44835274     261034
# 3      Creola city  City   place     36572       251  36878729    2374530
# 4   Dauphin Island  Town   place     36528       251  16204185  413605152
#
#          Lat        Lon   Mean  Median  Stdev        sum_w
# ...

# %%
# Split regions

# Region 1: Northeast
# "Connecticut", "Delaware", "District of Columbia", "Maine", 
# "Maryland", "Massachusetts", "New Hampshire", "New Jersey", 
# "New York", "Pennsylvania", "Rhode Island","Vermont"

northeast = econ_df.loc[(econ_df["State_Name"] == "Connecticut") | 
                        (econ_df["State_Name"] == "Delaware") | 
                        (econ_df["State_Name"] == "District of Columbia") | 
                        (econ_df["State_Name"] == "Maine") | 
                        (econ_df["State_Name"] == "Maryland") | 
                        (econ_df["State_Name"] == "Massachusetts") | 
                        (econ_df["State_Name"] == "New Hampshire") | 
                        (econ_df["State_Name"] == "New Jersey") | 
                        (econ_df["State_Name"] == "New York") | 
                        (econ_df["State_Name"] == "Pennsylvania") | 
                        (econ_df["State_Name"] == "Rhode Island") | 
                        (econ_df["State_Name"] == "Vermont"), :]

# Region 2: Midwest 
# "Illinois", "Indiana", "Iowa", "Kansas", "Michigan","Minnesota", 
# "Missouri", "Nebraska", "North Dakota", "Ohio", "South Dakota", 
# "Wisconsin"

midwest = econ_df.loc[(econ_df["State_Name"] == "Illinois") | 
                        (econ_df["State_Name"] == "Indiana") | 
                        (econ_df["State_Name"] == "Iowa") | 
                        (econ_df["State_Name"] == "Kansas") | 
                        (econ_df["State_Name"] == "Michigan") | 
                        (econ_df["State_Name"] == "Minnesota") | 
                        (econ_df["State_Name"] == "Missouri") | 
                        (econ_df["State_Name"] == "Nebraska") | 
                        (econ_df["State_Name"] == "North Dakota") | 
                        (econ_df["State_Name"] == "Ohio") | 
                        (econ_df["State_Name"] == "South Dakota") | 
                        (econ_df["State_Name"] == "Wisconsin"), :]

# Region 3: Southeast
# "Alabama", "Arkansas", "Florida", "Georgia", "Kentucky", "Louisiana", 
# "Mississippi", "North Carolina", "South Carolina", "Tennessee",
# "Virginia", "West Virginia"

southeast = econ_df.loc[(econ_df["State_Name"] == "Alabama") | 
                        (econ_df["State_Name"] == "Arkansas") | 
                        (econ_df["State_Name"] == "Florida") | 
                        (econ_df["State_Name"] == "Georgia") | 
                        (econ_df["State_Name"] == "Kentucky") | 
                        (econ_df["State_Name"] == "Louisiana") | 
                        (econ_df["State_Name"] == "Mississippi") | 
                        (econ_df["State_Name"] == "North Carolina") | 
                        (econ_df["State_Name"] == "South Carolina") | 
                        (econ_df["State_Name"] == "Tennesse") | 
                        (econ_df["State_Name"] == "Virginia") | 
                        (econ_df["State_Name"] == "West Virginia"), :]

# Region 4: Southwest
# "Arizona", "New Mexico", "Oklahoma", "Texas"

southwest = econ_df.loc[(econ_df["State_Name"] == "Arizona") | 
                        (econ_df["State_Name"] == "New Mexico") | 
                        (econ_df["State_Name"] == "Oklahoma") | 
                        (econ_df["State_Name"] == "Texas"), :]
    
# Region 5: West
# "Alaska", "California", "Colorado", "Hawaii", "Idaho", "Montana", 
# "Nevada", "Oregon", "Utah", "Washington", "Wyoming"

west = econ_df.loc[(econ_df["State_Name"] == "Alaska") | 
                    (econ_df["State_Name"] == "California") | 
                    (econ_df["State_Name"] == "Colorado") | 
                    (econ_df["State_Name"] == "Hawaii") | 
                    (econ_df["State_Name"] == "Idaho") | 
                    (econ_df["State_Name"] == "Montana") | 
                    (econ_df["State_Name"] == "Nevada") | 
                    (econ_df["State_Name"] == "Oregon") | 
                    (econ_df["State_Name"] == "Utah") | 
                    (econ_df["State_Name"] == "Washington") | 
                    (econ_df["State_Name"] == "Wyoming"), :]

# %%
# Check Northeast region
northeast.head()
# Out:
#           id  State_Code   State_Name State_ab             County        City  \
# 5394  901151           9  Connecticut       CT   Fairfield County      Bethel
# 5395  901161           9  Connecticut       CT   Fairfield County      Wilton
# 5396  901171           9  Connecticut       CT     Tolland County   Ellington
# 5397  901181           9  Connecticut       CT   New Haven County  East Haven
# 5398  901191           9  Connecticut       CT  New London County      Groton
#
#                   Place     Type Primary  Zip_Code Area_Code     ALand  \
# 5394             Bethel      CDP   place      6801       203  10593561
# 5395         Cannondale      CDP   place      6897       203    801282
# 5396       Crystal Lake      CDP   place      6029       860  20253178
# 5397         East Haven      CDP   place      6512       203  31846047
# 5398  Groton Long Point  Borough   place      6340       860   1106552
#
# ...

# %%
# Check Midwest Region
midwest.head()
# Out:
#             id  State_Code State_Name State_ab             County       City  \
# 8667  17012267          17   Illinois       IL  Washington County  Okawville
# 8668  17012277          17   Illinois       IL     McHenry County  Algonquin
# 8669  17012287          17   Illinois       IL        Cook County      Alsip
# 8670  17012297          17   Illinois       IL       Union County       Anna
# 8671  17012307          17   Illinois       IL      Bureau County     Cherry
#
#            Place     Type Primary  Zip_Code Area_Code     ALand  AWater  \
# 8667  Addieville  Village   place     62271       618   2727619       0
# 8668   Algonquin  Village   place     60102       847  31735947  460610
# 8669       Alsip  Village   place     60803       708  16900206  259691
# 8670   Anna city     City   place     62906       618   9202887   49041
# 8671   Arlington  Village   place     61317       815   1021570       0
#
#             Lat        Lon    Mean  Median  Stdev        sum_w
# ...

# %%
# Check Southeast Region
southeast.head()
# Out:
#         id  State_Code State_Name State_ab          County            City  \
# 0  1011000           1    Alabama       AL   Mobile County       Chickasaw
# 1  1011010           1    Alabama       AL  Barbour County      Louisville
# 2  1011020           1    Alabama       AL   Shelby County      Columbiana
# 3  1011030           1    Alabama       AL   Mobile County         Satsuma
# 4  1011040           1    Alabama       AL   Mobile County  Dauphin Island
#
#              Place  Type Primary  Zip_Code Area_Code     ALand     AWater  \
# 0   Chickasaw city  City   place     36611       251  10894952     909156
# 1        Clio city  City   place     36048       334  26070325      23254
# 2  Columbiana city  City   place     35051       205  44835274     261034
# 3      Creola city  City   place     36572       251  36878729    2374530
# 4   Dauphin Island  Town   place     36528       251  16204185  413605152
#
#          Lat        Lon   Mean  Median  Stdev        sum_w
# ...

# %%
# Check Southwest Region
southwest.head()
# Out:
#          id  State_Code State_Name State_ab           County         City  \
# 631  401539           4    Arizona       AZ      Pima County        Sells
# 632  401549           4    Arizona       AZ     Pinal County         Eloy
# 633  401559           4    Arizona       AZ    Mohave County  Littlefield
# 634  401569           4    Arizona       AZ   Cochise County        Bowie
# 635  401579           4    Arizona       AZ  Coconino County    Tuba City
#
#             Place Type Primary  Zip_Code Area_Code     ALand  AWater  \
# 631    Ali Molina  CDP   place     85634       520   1996741       0
# 632  Arizona City  CDP   place     85131       520  15901047  186302
# 633    Beaver Dam  CDP   place     86432       928  21799318       0
# 634         Bowie  CDP   place     85605       520   4393141       0
# 635       Cameron  CDP   place     86045       928  48495778   43135
#
#            Lat         Lon   Mean  Median  Stdev        sum_w
# ...

# %%
# Check West Region
west.head()
# Out:
#          id  State_Code State_Name State_ab                    County  \
# 526  201360           2     Alaska       AK      Kusilvak Census Area
# 527  201370           2     Alaska       AK            Denali Borough
# 528  201380           2     Alaska       AK       North Slope Borough
# 529  201390           2     Alaska       AK  Northwest Arctic Borough
# 530  201400           2     Alaska       AK      Kusilvak Census Area
#
#          City          Place  Type Primary  Zip_Code Area_Code      ALand  \
# 526  Alakanuk  Alakanuk city  City   place     99554       907   76485032
# 527  Anderson  Anderson city  City   place     99744       907  113285111
# 528    Barrow    Barrow city  City   place     99723       907   48786920
# 529  Buckland  Buckland city  City   place     99727       907    3640031
# 530    Chevak    Chevak city  City   place     99563       907    2562639
#
#        AWater        Lat         Lon   Mean  Median  Stdev       sum_w
# ...
